# %%
import numpy as np 
import pandas as pd 
import pandas_ta as ta
import ccxt
from datetime import datetime
from xgboost import XGBRegressor
import optuna 
from tqdm.auto import tqdm
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv("train.csv") 
submission = pd.read_csv("sample_submission.csv")

# %%
train['일시'] = pd.to_datetime(train['일시'])

# Fill missing values with ffill and bfill
train.fillna(method='ffill', inplace=True)
train.fillna(method='bfill', inplace=True)

# %%
train['month'] = train['일시'].dt.month
train['day'] = train['일시'].dt.day
train['week_of_month'] = train['일시'].dt.day.apply(lambda x: (x - 1) // 7 + 1)

# %%
X = train[["최고기온", "최저기온", "일교차", "강수량", "평균습도", "평균풍속", "일조합", "일사합", "일조율", "month", "day", "week_of_month"]]
y = train["평균기온"]

# %%
grouped = X.groupby(['month', 'week_of_month']).agg(['mean', 'median', 'std'])
grouped = grouped.drop(columns=[('day', 'mean'), ('day', 'median'), ('day', 'std')])

# %%
merged_df = pd.merge(X, grouped, on=['month', 'week_of_month'], how='left')
# Out:
# /tmp/ipykernel_711/112521591.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   merged_df = pd.merge(X, grouped, on=['month', 'week_of_month'], how='left')

# %%
merged_df.drop(columns={"최고기온", "최저기온", "일교차", "강수량", "평균습도", "평균풍속", "일조합", "일사합", "일조율"}, inplace=True)

# %%
def stratified_month_split(X, y, test_size=0.2): 
    X_train = pd.DataFrame(columns=X.columns) 
    X_val = pd.DataFrame(columns=X.columns)
    y_train = pd.Series(dtype=float)
    y_val = pd.Series(dtype=float) 

    for month in X["month"].unique():
        X_month = X[X["month"] == month] 
        y_month = y[X["month"] == month] 
        X_train_month, X_val_month, y_train_month, y_val_month = train_test_split(
            X_month, y_month, test_size=test_size, random_state=42
        ) 

        # Append to train and test sets
        X_train = pd.concat([X_train, X_train_month])
        X_val = pd.concat([X_val, X_val_month])
        y_train = pd.concat([y_train, y_train_month])
        y_val = pd.concat([y_val, y_val_month])

    return X_train, X_val, y_train, y_val

# %%
X_train, X_val, y_train, y_val = stratified_month_split(merged_df, y, test_size=0.2)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((18406, 30), (4605, 30), (18406,), (4605,))

# %%
X_train['month'] = X_train['month'].astype(int)
X_train['day'] = X_train['day'].astype(int)
X_train['week_of_month'] = X_train['week_of_month'].astype(int)

X_val['month'] = X_val['month'].astype(int)
X_val['day'] = X_val['day'].astype(int)
X_val['week_of_month'] = X_val['week_of_month'].astype(int)

# %%
def objective(trial): 
    param = {
        "objective": "reg:squarederror",  # Objective for regression
        "n_estimators": 100, 
        "random_state": 42, 
        "tree_method": "gpu_hist",  # Assuming you have a compatible GPU
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.3, log=True), 
        "subsample": trial.suggest_float("subsample", 0.6, 1.0), 
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0), 
        "max_depth": trial.suggest_int("max_depth", 3, 10), 
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 300), 
        "gamma": trial.suggest_float("gamma", 0, 0.4), 
        "alpha": trial.suggest_float("alpha", 0, 10), 
        "lambda": trial.suggest_float("lambda", 1, 10),
        "enable_categorical": True, 
    }
    reg_xgb = XGBRegressor(**param)
    reg_xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=30, verbose=False)
    predictions = reg_xgb.predict(X_val) 
    mae = mean_absolute_error(y_val, predictions)
    return mae

# %%
study = optuna.create_study(direction="minimize") 
study.optimize(objective, n_trials=500)
# Out:
# [I 2023-12-31 11:49:00,637] A new study created in memory with name: no-name-cf5be5e0-fe64-4704-9a1d-b68d92787081
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:01,463] Trial 0 finished with value: 2.5398050983187046 and parameters: {'learning_rate': 0.09200164999904892, 'subsample': 0.8736777146092519, 'colsample_bytree': 0.8331830629599828, 'max_depth': 7, 'min_child_weight': 234, 'gamma': 0.1250894946144888, 'alpha': 5.456697573734499, 'lambda': 4.697753710313035}. Best is trial 0 with value: 2.5398050983187046.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:01,718] Trial 1 finished with value: 3.2291445122259574 and parameters: {'learning_rate': 0.02028178389852096, 'subsample': 0.6545715669861824, 'colsample_bytree': 0.9973444111549655, 'max_depth': 6, 'min_child_weight': 127, 'gamma': 0.03504490196146422, 'alpha': 3.5028422428476533, 'lambda': 5.3703996098140525}. Best is trial 0 with value: 2.5398050983187046.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:01,844] Trial 2 finished with value: 2.546224823068589 and parameters: {'learning_rate': 0.12940317109734956, 'subsample': 0.8135986753605319, 'colsample_bytree': 0.7116624479582709, 'max_depth': 3, 'min_child_weight': 74, 'gamma': 0.28587241626520166, 'alpha': 1.5797464778207504, 'lambda': 9.486232945814324}. Best is trial 0 with value: 2.5398050983187046.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:02,081] Trial 3 finished with value: 2.53959986470486 and parameters: {'learning_rate': 0.16302662340300353, 'subsample': 0.8747016673875083, 'colsample_bytree': 0.6385863418695126, 'max_depth': 10, 'min_child_weight': 300, 'gamma': 0.37148017533933697, 'alpha': 9.093212449568387, 'lambda': 1.1335603394870322}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:02,292] Trial 4 finished with value: 2.7102498592460584 and parameters: {'learning_rate': 0.028171998865497688, 'subsample': 0.8004165476926064, 'colsample_bytree': 0.6220123097379037, 'max_depth': 5, 'min_child_weight': 80, 'gamma': 0.21097558132416072, 'alpha': 2.2334933722949324, 'lambda': 9.602462543228178}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:02,561] Trial 5 finished with value: 2.5424304918302516 and parameters: {'learning_rate': 0.07644258367647652, 'subsample': 0.7045457669051108, 'colsample_bytree': 0.8465205263424154, 'max_depth': 6, 'min_child_weight': 61, 'gamma': 0.18489135196406942, 'alpha': 0.06149091132614859, 'lambda': 3.9887068256944387}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:02,728] Trial 6 finished with value: 2.540811229052586 and parameters: {'learning_rate': 0.0827039271896853, 'subsample': 0.8571686347821982, 'colsample_bytree': 0.9247134699195807, 'max_depth': 4, 'min_child_weight': 51, 'gamma': 0.33773714238537955, 'alpha': 3.4152952059144304, 'lambda': 5.0773304439336036}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:02,934] Trial 7 finished with value: 2.543218368571353 and parameters: {'learning_rate': 0.06590376560202345, 'subsample': 0.8912152591246738, 'colsample_bytree': 0.6233253111289077, 'max_depth': 5, 'min_child_weight': 81, 'gamma': 0.3354679622929495, 'alpha': 8.754819349882712, 'lambda': 3.6221876323578996}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:03,139] Trial 8 finished with value: 2.543068019707933 and parameters: {'learning_rate': 0.1377111941343806, 'subsample': 0.6109522986813439, 'colsample_bytree': 0.8174186601403614, 'max_depth': 6, 'min_child_weight': 27, 'gamma': 0.27480055960888566, 'alpha': 8.313500252576008, 'lambda': 4.874482145593181}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:03,266] Trial 9 finished with value: 2.546131400052422 and parameters: {'learning_rate': 0.13163410865638142, 'subsample': 0.8129623340255411, 'colsample_bytree': 0.6445985554617819, 'max_depth': 3, 'min_child_weight': 185, 'gamma': 0.19314233102110864, 'alpha': 0.12955151827721334, 'lambda': 9.846877774193183}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:03,597] Trial 10 finished with value: 7.820458355000915 and parameters: {'learning_rate': 0.00612630025268961, 'subsample': 0.9897641393347172, 'colsample_bytree': 0.7385388187706095, 'max_depth': 10, 'min_child_weight': 291, 'gamma': 0.36855823151846406, 'alpha': 6.855444928117519, 'lambda': 1.155716721208182}. Best is trial 3 with value: 2.53959986470486.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:03,803] Trial 11 finished with value: 2.538858322371748 and parameters: {'learning_rate': 0.27313210015313444, 'subsample': 0.9470458448136898, 'colsample_bytree': 0.8794602529739598, 'max_depth': 9, 'min_child_weight': 299, 'gamma': 0.07521928681161688, 'alpha': 6.7139524263707075, 'lambda': 1.1865307434304793}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:04,030] Trial 12 finished with value: 2.539458799705993 and parameters: {'learning_rate': 0.2931023071537159, 'subsample': 0.9669379108084487, 'colsample_bytree': 0.911402545509669, 'max_depth': 10, 'min_child_weight': 300, 'gamma': 5.5832575875408574e-05, 'alpha': 9.941489466585253, 'lambda': 1.0556171025296055}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:04,231] Trial 13 finished with value: 2.5401020705077015 and parameters: {'learning_rate': 0.2604047745428218, 'subsample': 0.9960195477494442, 'colsample_bytree': 0.8923086461476422, 'max_depth': 8, 'min_child_weight': 242, 'gamma': 0.008076914550313261, 'alpha': 6.974522614014197, 'lambda': 2.532262323235985}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:04,446] Trial 14 finished with value: 2.5398384800462717 and parameters: {'learning_rate': 0.2655647277465452, 'subsample': 0.9384326130186599, 'colsample_bytree': 0.9548249677502568, 'max_depth': 9, 'min_child_weight': 253, 'gamma': 0.08206893318775564, 'alpha': 6.841508672134751, 'lambda': 7.081846032196941}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:04,760] Trial 15 finished with value: 4.414285756234367 and parameters: {'learning_rate': 0.013867652706781764, 'subsample': 0.9341752560267087, 'colsample_bytree': 0.8885345010612125, 'max_depth': 9, 'min_child_weight': 191, 'gamma': 0.07110001989824583, 'alpha': 9.614218920875157, 'lambda': 2.395414075013125}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:05,025] Trial 16 finished with value: 2.554193058170532 and parameters: {'learning_rate': 0.0452021175271867, 'subsample': 0.7271758673923984, 'colsample_bytree': 0.9746114814594449, 'max_depth': 8, 'min_child_weight': 267, 'gamma': 0.12302153720753727, 'alpha': 9.98158150585127, 'lambda': 7.263239102718124}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:05,239] Trial 17 finished with value: 2.539242748867247 and parameters: {'learning_rate': 0.27541568622450885, 'subsample': 0.9469047447298756, 'colsample_bytree': 0.7631846963144807, 'max_depth': 9, 'min_child_weight': 199, 'gamma': 0.047704483178223046, 'alpha': 5.044213937771727, 'lambda': 2.311498412204128}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:05,464] Trial 18 finished with value: 2.541009108868471 and parameters: {'learning_rate': 0.19363085954344866, 'subsample': 0.9270403621601563, 'colsample_bytree': 0.767258008912022, 'max_depth': 8, 'min_child_weight': 200, 'gamma': 0.12334330149283962, 'alpha': 5.076111373854526, 'lambda': 2.4872920380842944}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:05,773] Trial 19 finished with value: 2.555260203028023 and parameters: {'learning_rate': 0.04244765791773525, 'subsample': 0.7660801819806506, 'colsample_bytree': 0.7004011047251107, 'max_depth': 9, 'min_child_weight': 131, 'gamma': 0.05649207411801563, 'alpha': 5.790372813386144, 'lambda': 6.596795391829479}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:06,075] Trial 20 finished with value: 5.823534741324659 and parameters: {'learning_rate': 0.009845395698279342, 'subsample': 0.913786093013809, 'colsample_bytree': 0.7799084565743196, 'max_depth': 7, 'min_child_weight': 159, 'gamma': 0.10444686333969466, 'alpha': 3.856175252041835, 'lambda': 3.1421463579614892}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:06,277] Trial 21 finished with value: 2.5397827420015613 and parameters: {'learning_rate': 0.29984392659543085, 'subsample': 0.9666656054920296, 'colsample_bytree': 0.8724210621834255, 'max_depth': 10, 'min_child_weight': 274, 'gamma': 0.01045862985293531, 'alpha': 7.846150570798054, 'lambda': 1.6501463144796302}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:06,533] Trial 22 finished with value: 2.540935390515174 and parameters: {'learning_rate': 0.19393634381867444, 'subsample': 0.9825234281313964, 'colsample_bytree': 0.9251422719566859, 'max_depth': 9, 'min_child_weight': 224, 'gamma': 0.0005151165509897463, 'alpha': 4.453317980173953, 'lambda': 1.8414198947179923}. Best is trial 11 with value: 2.538858322371748.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:06,777] Trial 23 finished with value: 2.538720631943884 and parameters: {'learning_rate': 0.2156334802198624, 'subsample': 0.9548705310336143, 'colsample_bytree': 0.7914352404936026, 'max_depth': 10, 'min_child_weight': 215, 'gamma': 0.044946538549926064, 'alpha': 6.173164955199319, 'lambda': 1.8802677551628921}. Best is trial 23 with value: 2.538720631943884.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:07,019] Trial 24 finished with value: 2.5383436684749707 and parameters: {'learning_rate': 0.2027674809735755, 'subsample': 0.8481744375461391, 'colsample_bytree': 0.7834996520789251, 'max_depth': 8, 'min_child_weight': 219, 'gamma': 0.158528742298348, 'alpha': 6.197755655381853, 'lambda': 3.2329522636913475}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:07,345] Trial 25 finished with value: 2.538780487332246 and parameters: {'learning_rate': 0.10355962067930512, 'subsample': 0.8443230782317706, 'colsample_bytree': 0.8083552092655772, 'max_depth': 8, 'min_child_weight': 162, 'gamma': 0.16774543289569444, 'alpha': 6.12866270720097, 'lambda': 3.5635223726153713}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:07,640] Trial 26 finished with value: 2.539010836642547 and parameters: {'learning_rate': 0.1032638484982458, 'subsample': 0.8510972178693519, 'colsample_bytree': 0.7993332294255039, 'max_depth': 7, 'min_child_weight': 157, 'gamma': 0.16509268102826435, 'alpha': 6.040032065900004, 'lambda': 3.877523526176974}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:07,958] Trial 27 finished with value: 2.5401033972414067 and parameters: {'learning_rate': 0.06203942547785214, 'subsample': 0.771788356810372, 'colsample_bytree': 0.6804224541848553, 'max_depth': 8, 'min_child_weight': 121, 'gamma': 0.2294841561316184, 'alpha': 7.448314482325113, 'lambda': 3.0870529256619506}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:08,226] Trial 28 finished with value: 2.540014634461958 and parameters: {'learning_rate': 0.16838610899943995, 'subsample': 0.8387913874877675, 'colsample_bytree': 0.7320144043039584, 'max_depth': 8, 'min_child_weight': 217, 'gamma': 0.15256703219064538, 'alpha': 6.156443572267126, 'lambda': 6.085733860674722}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:08,504] Trial 29 finished with value: 2.540131217387548 and parameters: {'learning_rate': 0.10984159696351342, 'subsample': 0.9041683901899715, 'colsample_bytree': 0.8405546386824013, 'max_depth': 7, 'min_child_weight': 175, 'gamma': 0.23960501774805745, 'alpha': 4.276833088471229, 'lambda': 4.319858443854242}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:08,759] Trial 30 finished with value: 2.5393803464932754 and parameters: {'learning_rate': 0.18483734942507213, 'subsample': 0.7692745401936761, 'colsample_bytree': 0.8138003465162978, 'max_depth': 8, 'min_child_weight': 221, 'gamma': 0.16638747236327361, 'alpha': 5.630066068673782, 'lambda': 3.092744928913934}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:09,014] Trial 31 finished with value: 2.5395084603147806 and parameters: {'learning_rate': 0.2131068623227457, 'subsample': 0.8768522909986076, 'colsample_bytree': 0.8565447309426523, 'max_depth': 9, 'min_child_weight': 248, 'gamma': 0.08750808382271895, 'alpha': 6.518282320141272, 'lambda': 1.8451516112554196}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:09,248] Trial 32 finished with value: 2.542018051780073 and parameters: {'learning_rate': 0.22266120047337057, 'subsample': 0.8301805065642014, 'colsample_bytree': 0.7885221327805653, 'max_depth': 10, 'min_child_weight': 107, 'gamma': 0.15149425233035912, 'alpha': 7.57307144127311, 'lambda': 3.4340519778781204}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:09,535] Trial 33 finished with value: 2.540171416348795 and parameters: {'learning_rate': 0.14316366282090254, 'subsample': 0.9591298892757301, 'colsample_bytree': 0.8215407799876372, 'max_depth': 9, 'min_child_weight': 173, 'gamma': 0.03141870431126734, 'alpha': 5.404105698254452, 'lambda': 4.525753448578558}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:09,877] Trial 34 finished with value: 2.5406767018066554 and parameters: {'learning_rate': 0.10508036892416744, 'subsample': 0.909790613945686, 'colsample_bytree': 0.7461916557644076, 'max_depth': 10, 'min_child_weight': 137, 'gamma': 0.1066965690107739, 'alpha': 6.341125052734052, 'lambda': 1.6733356823775776}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:10,134] Trial 35 finished with value: 2.5391089045934288 and parameters: {'learning_rate': 0.15627474142098524, 'subsample': 0.8857211373916877, 'colsample_bytree': 0.8679897012378315, 'max_depth': 8, 'min_child_weight': 268, 'gamma': 0.1391184409190399, 'alpha': 7.9901485101563505, 'lambda': 5.596213372154948}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:10,428] Trial 36 finished with value: 2.544982654844106 and parameters: {'learning_rate': 0.05269311871121882, 'subsample': 0.8641134400340612, 'colsample_bytree': 0.8015506972587558, 'max_depth': 7, 'min_child_weight': 211, 'gamma': 0.25280439137526545, 'alpha': 7.167345804064334, 'lambda': 2.8472811716588993}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:10,675] Trial 37 finished with value: 2.5390100201326105 and parameters: {'learning_rate': 0.22644472840338425, 'subsample': 0.7950354891619713, 'colsample_bytree': 0.7130739110603067, 'max_depth': 9, 'min_child_weight': 102, 'gamma': 0.20770301043763054, 'alpha': 4.591488260972116, 'lambda': 2.1696137919729375}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:11,004] Trial 38 finished with value: 2.623000426843487 and parameters: {'learning_rate': 0.03201370035978321, 'subsample': 0.7296101069147582, 'colsample_bytree': 0.8377554681114664, 'max_depth': 10, 'min_child_weight': 170, 'gamma': 0.06594325986432101, 'alpha': 2.7998692504000475, 'lambda': 1.3715616813675986}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:11,261] Trial 39 finished with value: 2.540317815198249 and parameters: {'learning_rate': 0.08296559541627853, 'subsample': 0.8273332815073066, 'colsample_bytree': 0.7582750631888586, 'max_depth': 6, 'min_child_weight': 230, 'gamma': 0.030442185289954404, 'alpha': 8.378975459051489, 'lambda': 8.767150422762771}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:11,493] Trial 40 finished with value: 3.1466189556957973 and parameters: {'learning_rate': 0.02105636815103474, 'subsample': 0.6480926219477214, 'colsample_bytree': 0.7839962475200121, 'max_depth': 5, 'min_child_weight': 284, 'gamma': 0.17794470165158016, 'alpha': 5.390838931097912, 'lambda': 4.306068085523606}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:11,754] Trial 41 finished with value: 2.5384961396203365 and parameters: {'learning_rate': 0.22244427799108282, 'subsample': 0.7912604709817685, 'colsample_bytree': 0.6698301566905096, 'max_depth': 9, 'min_child_weight': 102, 'gamma': 0.21128257957065655, 'alpha': 4.5570632407702885, 'lambda': 2.1307690581268757}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:12,050] Trial 42 finished with value: 2.539922772132742 and parameters: {'learning_rate': 0.12495580490854598, 'subsample': 0.7923565296433599, 'colsample_bytree': 0.6790730005648746, 'max_depth': 9, 'min_child_weight': 147, 'gamma': 0.28139337408155857, 'alpha': 6.434422871345675, 'lambda': 3.5923437075880997}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:12,343] Trial 43 finished with value: 2.539897932467515 and parameters: {'learning_rate': 0.16472154368192313, 'subsample': 0.7310791646031951, 'colsample_bytree': 0.6013059641860562, 'max_depth': 10, 'min_child_weight': 99, 'gamma': 0.20825639596636897, 'alpha': 3.3235716522068115, 'lambda': 1.9994533894247837}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:12,594] Trial 44 finished with value: 2.546070824111129 and parameters: {'learning_rate': 0.23291290521358876, 'subsample': 0.8059101806762441, 'colsample_bytree': 0.6466195660205797, 'max_depth': 8, 'min_child_weight': 4, 'gamma': 0.09884165433520067, 'alpha': 4.828347826190712, 'lambda': 2.7895647339317358}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:12,932] Trial 45 finished with value: 2.543610528636477 and parameters: {'learning_rate': 0.12400115835964172, 'subsample': 0.8531190580620431, 'colsample_bytree': 0.7202469260832522, 'max_depth': 9, 'min_child_weight': 65, 'gamma': 0.3037934678748956, 'alpha': 5.898364121006375, 'lambda': 1.03775221393423}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:13,189] Trial 46 finished with value: 2.5397326910845233 and parameters: {'learning_rate': 0.23959968717295746, 'subsample': 0.8959101925354398, 'colsample_bytree': 0.688592056962713, 'max_depth': 10, 'min_child_weight': 117, 'gamma': 0.2266475678577568, 'alpha': 1.430214835208119, 'lambda': 1.44280163893329}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:13,622] Trial 47 finished with value: 2.5434552181156174 and parameters: {'learning_rate': 0.07501106104567638, 'subsample': 0.7817669455689759, 'colsample_bytree': 0.9354403385892068, 'max_depth': 8, 'min_child_weight': 41, 'gamma': 0.18836359189609897, 'alpha': 6.641415089377602, 'lambda': 3.9504456772646463}. Best is trial 24 with value: 2.5383436684749707.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:13,930] Trial 48 finished with value: 2.5374136409658563 and parameters: {'learning_rate': 0.18160665432668083, 'subsample': 0.6947464502296394, 'colsample_bytree': 0.8926338837153864, 'max_depth': 9, 'min_child_weight': 257, 'gamma': 0.13728001402863468, 'alpha': 4.036113173479847, 'lambda': 2.726113815085202}. Best is trial 48 with value: 2.5374136409658563.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:14,247] Trial 49 finished with value: 2.538586074928475 and parameters: {'learning_rate': 0.09282469049061838, 'subsample': 0.6803597421938112, 'colsample_bytree': 0.9018311810297928, 'max_depth': 10, 'min_child_weight': 240, 'gamma': 0.2612352465020895, 'alpha': 3.984736726846102, 'lambda': 3.400924153614497}. Best is trial 48 with value: 2.5374136409658563.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:14,560] Trial 50 finished with value: 2.537172508267089 and parameters: {'learning_rate': 0.1458691648117748, 'subsample': 0.6737153273109053, 'colsample_bytree': 0.9905271597978307, 'max_depth': 10, 'min_child_weight': 256, 'gamma': 0.26137384302775857, 'alpha': 2.4620147557133008, 'lambda': 5.260432746435768}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:14,866] Trial 51 finished with value: 2.539266881572243 and parameters: {'learning_rate': 0.14614944206435382, 'subsample': 0.6763064217843225, 'colsample_bytree': 0.9690970563096075, 'max_depth': 10, 'min_child_weight': 256, 'gamma': 0.2617406632605181, 'alpha': 2.518147979259155, 'lambda': 2.653405663505048}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:15,099] Trial 52 finished with value: 2.538725590671086 and parameters: {'learning_rate': 0.17424959035675147, 'subsample': 0.6659512137582727, 'colsample_bytree': 0.9036480660550541, 'max_depth': 10, 'min_child_weight': 240, 'gamma': 0.31899708120183295, 'alpha': 1.6606022950551835, 'lambda': 5.1869877707562235}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:15,355] Trial 53 finished with value: 2.540656911711513 and parameters: {'learning_rate': 0.19235708903934243, 'subsample': 0.6295064998038544, 'colsample_bytree': 0.9907336619511412, 'max_depth': 10, 'min_child_weight': 258, 'gamma': 0.261109901728136, 'alpha': 4.08805551902915, 'lambda': 2.15736952694786}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:15,667] Trial 54 finished with value: 2.538679421805371 and parameters: {'learning_rate': 0.12124929463970097, 'subsample': 0.6946180694115731, 'colsample_bytree': 0.9488706288964417, 'max_depth': 9, 'min_child_weight': 280, 'gamma': 0.29636965023321055, 'alpha': 3.2030198818480193, 'lambda': 4.822572925619099}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:15,994] Trial 55 finished with value: 2.540807780828509 and parameters: {'learning_rate': 0.08749948421540386, 'subsample': 0.6956710515014305, 'colsample_bytree': 0.9440894658378967, 'max_depth': 9, 'min_child_weight': 274, 'gamma': 0.29334033919030694, 'alpha': 3.233793140816055, 'lambda': 4.8682343763326905}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:16,296] Trial 56 finished with value: 2.5399712369419696 and parameters: {'learning_rate': 0.12199481733876304, 'subsample': 0.701670369670153, 'colsample_bytree': 0.9862635907558537, 'max_depth': 9, 'min_child_weight': 287, 'gamma': 0.35319920722411824, 'alpha': 3.714432917010437, 'lambda': 5.6059425009212465}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:16,600] Trial 57 finished with value: 2.5379530792982683 and parameters: {'learning_rate': 0.15296953569182878, 'subsample': 0.6055719670883528, 'colsample_bytree': 0.957902879090624, 'max_depth': 9, 'min_child_weight': 243, 'gamma': 0.39724856241792683, 'alpha': 1.8948127280521145, 'lambda': 6.2570225802125625}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:16,768] Trial 58 finished with value: 2.549527726264005 and parameters: {'learning_rate': 0.06603258193363357, 'subsample': 0.6199582453143371, 'colsample_bytree': 0.970128452649196, 'max_depth': 3, 'min_child_weight': 237, 'gamma': 0.3301776998252993, 'alpha': 0.8369600495515661, 'lambda': 7.227156673146017}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:17,095] Trial 59 finished with value: 2.538874919990181 and parameters: {'learning_rate': 0.09345077637325126, 'subsample': 0.745789347027596, 'colsample_bytree': 0.9992210201151294, 'max_depth': 9, 'min_child_weight': 201, 'gamma': 0.36441428840127055, 'alpha': 1.8214153838156855, 'lambda': 8.213637942061581}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:17,272] Trial 60 finished with value: 2.542591727486327 and parameters: {'learning_rate': 0.1449279524229288, 'subsample': 0.6441841782993956, 'colsample_bytree': 0.9232683398452924, 'max_depth': 4, 'min_child_weight': 264, 'gamma': 0.3963204986749142, 'alpha': 2.115851493847147, 'lambda': 6.747723933315831}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:17,568] Trial 61 finished with value: 2.5390433294632664 and parameters: {'learning_rate': 0.11836333731006875, 'subsample': 0.6046485374570418, 'colsample_bytree': 0.9553627606901947, 'max_depth': 9, 'min_child_weight': 280, 'gamma': 0.38947980183526604, 'alpha': 2.946425162789091, 'lambda': 5.37997329529657}. Best is trial 50 with value: 2.537172508267089.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:17,871] Trial 62 finished with value: 2.536341567588616 and parameters: {'learning_rate': 0.15796659574937344, 'subsample': 0.6839290113429803, 'colsample_bytree': 0.9558383129094158, 'max_depth': 9, 'min_child_weight': 249, 'gamma': 0.30847224747971136, 'alpha': 3.683769666122139, 'lambda': 6.004028730469736}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:18,090] Trial 63 finished with value: 2.54006241559408 and parameters: {'learning_rate': 0.2572216029073706, 'subsample': 0.6856980510058514, 'colsample_bytree': 0.9004848433907107, 'max_depth': 10, 'min_child_weight': 243, 'gamma': 0.3137507415913692, 'alpha': 3.590068045418276, 'lambda': 5.891199974334389}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:18,346] Trial 64 finished with value: 2.5387867077421413 and parameters: {'learning_rate': 0.196132987961839, 'subsample': 0.6285689273582796, 'colsample_bytree': 0.9156907204293284, 'max_depth': 9, 'min_child_weight': 230, 'gamma': 0.22249482213030086, 'alpha': 4.063250218570529, 'lambda': 6.248466381055995}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:18,604] Trial 65 finished with value: 2.538528185409456 and parameters: {'learning_rate': 0.16366575499021904, 'subsample': 0.7129705558573718, 'colsample_bytree': 0.9804299728252567, 'max_depth': 10, 'min_child_weight': 251, 'gamma': 0.26706346301425304, 'alpha': 2.496042897699721, 'lambda': 7.594486738537775}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:18,899] Trial 66 finished with value: 2.5384989828232127 and parameters: {'learning_rate': 0.15762962139080064, 'subsample': 0.6602839765853132, 'colsample_bytree': 0.9812468594681507, 'max_depth': 8, 'min_child_weight': 253, 'gamma': 0.2402230397937295, 'alpha': 2.350725708587338, 'lambda': 7.643784173564135}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:19,094] Trial 67 finished with value: 2.5406088388393293 and parameters: {'learning_rate': 0.28698368966648563, 'subsample': 0.6596362102228366, 'colsample_bytree': 0.958548369547066, 'max_depth': 8, 'min_child_weight': 262, 'gamma': 0.23943117640594003, 'alpha': 1.180378575570801, 'lambda': 7.584222339110097}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:19,318] Trial 68 finished with value: 2.539351498290783 and parameters: {'learning_rate': 0.1996152608979401, 'subsample': 0.6382880072731747, 'colsample_bytree': 0.968238863567232, 'max_depth': 7, 'min_child_weight': 209, 'gamma': 0.19659550552032787, 'alpha': 2.158677348795148, 'lambda': 6.435412179056871}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:19,570] Trial 69 finished with value: 2.5405017862243255 and parameters: {'learning_rate': 0.14180617187212036, 'subsample': 0.7511103300011109, 'colsample_bytree': 0.9344251356697626, 'max_depth': 8, 'min_child_weight': 230, 'gamma': 0.13520599845494294, 'alpha': 0.5221981514343819, 'lambda': 8.584099116092633}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:19,761] Trial 70 finished with value: 2.5399673270499665 and parameters: {'learning_rate': 0.2524206382907732, 'subsample': 0.7120753489982536, 'colsample_bytree': 0.9968111731307662, 'max_depth': 8, 'min_child_weight': 192, 'gamma': 0.24334311859367747, 'alpha': 2.8864971329878157, 'lambda': 6.92420883530507}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:20,054] Trial 71 finished with value: 2.5384128965268338 and parameters: {'learning_rate': 0.15853417775609796, 'subsample': 0.7130683067167749, 'colsample_bytree': 0.9786767295980259, 'max_depth': 9, 'min_child_weight': 249, 'gamma': 0.2757434200964544, 'alpha': 2.5514162846024244, 'lambda': 7.655358733346535}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:20,350] Trial 72 finished with value: 2.538770269830099 and parameters: {'learning_rate': 0.1759788837197538, 'subsample': 0.6542409374015833, 'colsample_bytree': 0.979685342567458, 'max_depth': 9, 'min_child_weight': 295, 'gamma': 0.2778007367309252, 'alpha': 2.5391009470346715, 'lambda': 7.740407723331385}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:49:20,606] Trial 73 finished with value: 7.312509607669455 and parameters: {'learning_rate': 0.0069728242342596055, 'subsample': 0.6706150766698598, 'colsample_bytree': 0.9595647607827461, 'max_depth': 9, 'min_child_weight': 248, 'gamma': 0.21607536415759251, 'alpha': 4.596551847574358, 'lambda': 7.892318092336076}. Best is trial 62 with value: 2.536341567588616.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# ...
#   warnings.warn(
# [I 2023-12-31 11:51:33,493] Trial 475 finished with value: 2.5399597000362237 and parameters: {'learning_rate': 0.24064622660048715, 'subsample': 0.8131902929643713, 'colsample_bytree': 0.9056872694981474, 'max_depth': 5, 'min_child_weight': 274, 'gamma': 0.08040938166287054, 'alpha': 5.645452346320377, 'lambda': 8.328267530610761}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:33,739] Trial 476 finished with value: 2.5379070030232076 and parameters: {'learning_rate': 0.18808383136091844, 'subsample': 0.8414188522327569, 'colsample_bytree': 0.8772003429033675, 'max_depth': 8, 'min_child_weight': 288, 'gamma': 0.11422307582448207, 'alpha': 6.037184777808324, 'lambda': 5.318400065811435}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:34,016] Trial 477 finished with value: 2.5390406206871075 and parameters: {'learning_rate': 0.15849284450979798, 'subsample': 0.8209215207697214, 'colsample_bytree': 0.9877090096513441, 'max_depth': 9, 'min_child_weight': 265, 'gamma': 0.15386374505878125, 'alpha': 6.327398222112845, 'lambda': 5.716170398839787}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:34,279] Trial 478 finished with value: 2.5378234914967734 and parameters: {'learning_rate': 0.2219174110987273, 'subsample': 0.8346497410448961, 'colsample_bytree': 0.8957235974563985, 'max_depth': 9, 'min_child_weight': 271, 'gamma': 0.13143086585148342, 'alpha': 6.148996411849228, 'lambda': 8.523483480209116}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:34,557] Trial 479 finished with value: 2.5387786852907346 and parameters: {'learning_rate': 0.19871591287209722, 'subsample': 0.85785004097412, 'colsample_bytree': 0.8849926525100636, 'max_depth': 9, 'min_child_weight': 281, 'gamma': 0.1396350934125704, 'alpha': 6.535562001376078, 'lambda': 8.055973681271615}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:34,843] Trial 480 finished with value: 2.5802733815777703 and parameters: {'learning_rate': 0.03702732848890826, 'subsample': 0.8044010831487708, 'colsample_bytree': 0.6655064367542814, 'max_depth': 9, 'min_child_weight': 261, 'gamma': 0.10182165827126496, 'alpha': 5.840842874530575, 'lambda': 6.217714349607908}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:35,135] Trial 481 finished with value: 2.5370748685628794 and parameters: {'learning_rate': 0.1703508599314468, 'subsample': 0.800076664389296, 'colsample_bytree': 0.7660694281847332, 'max_depth': 9, 'min_child_weight': 269, 'gamma': 0.09021242397289342, 'alpha': 5.50831734271741, 'lambda': 5.927168987791013}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:35,387] Trial 482 finished with value: 2.53995013315089 and parameters: {'learning_rate': 0.15906892179018342, 'subsample': 0.8137050369853651, 'colsample_bytree': 0.8669537151042533, 'max_depth': 9, 'min_child_weight': 246, 'gamma': 0.120180597836854, 'alpha': 6.892703948393822, 'lambda': 8.26753509332086}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:35,674] Trial 483 finished with value: 2.537038206595616 and parameters: {'learning_rate': 0.2733300002538349, 'subsample': 0.7897423770928631, 'colsample_bytree': 0.8757301969529311, 'max_depth': 9, 'min_child_weight': 277, 'gamma': 0.11303040416298649, 'alpha': 6.211706766941759, 'lambda': 8.088435511318556}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:36,012] Trial 484 finished with value: 2.5371902926360037 and parameters: {'learning_rate': 0.18011101309990876, 'subsample': 0.7930227877217905, 'colsample_bytree': 0.8581250499693404, 'max_depth': 9, 'min_child_weight': 258, 'gamma': 0.13070477265312355, 'alpha': 6.656597736426285, 'lambda': 8.420037097037266}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:36,321] Trial 485 finished with value: 2.539945324890712 and parameters: {'learning_rate': 0.2132084102946205, 'subsample': 0.7168585023955523, 'colsample_bytree': 0.6814399557647258, 'max_depth': 9, 'min_child_weight': 266, 'gamma': 0.1651705729994359, 'alpha': 5.714807577843083, 'lambda': 5.783645684732489}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:36,646] Trial 486 finished with value: 2.537328284135357 and parameters: {'learning_rate': 0.14172411503111762, 'subsample': 0.8017285607937978, 'colsample_bytree': 0.8890045613760656, 'max_depth': 9, 'min_child_weight': 286, 'gamma': 0.147277913084876, 'alpha': 5.1497463339309375, 'lambda': 5.535826770775432}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:36,949] Trial 487 finished with value: 2.5380975829495216 and parameters: {'learning_rate': 0.2377042113311649, 'subsample': 0.7329803907192594, 'colsample_bytree': 0.8987272580243626, 'max_depth': 9, 'min_child_weight': 275, 'gamma': 0.29556006436121984, 'alpha': 6.449214857203528, 'lambda': 7.9368249927518715}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:37,195] Trial 488 finished with value: 2.537815151700303 and parameters: {'learning_rate': 0.29939387546702834, 'subsample': 0.8085690918914292, 'colsample_bytree': 0.8812330086237797, 'max_depth': 9, 'min_child_weight': 263, 'gamma': 0.12488655496210406, 'alpha': 5.971341188509725, 'lambda': 6.095751466667701}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:37,518] Trial 489 finished with value: 2.536687366786887 and parameters: {'learning_rate': 0.13108154468473093, 'subsample': 0.7871960462169092, 'colsample_bytree': 0.8666144375599143, 'max_depth': 9, 'min_child_weight': 253, 'gamma': 0.26101142629015717, 'alpha': 6.30212126950434, 'lambda': 5.050895873807736}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:37,850] Trial 490 finished with value: 2.5374366527119494 and parameters: {'learning_rate': 0.25567454250530786, 'subsample': 0.7824493561843427, 'colsample_bytree': 0.8480985577462365, 'max_depth': 8, 'min_child_weight': 270, 'gamma': 0.13609124590906632, 'alpha': 7.199352135045648, 'lambda': 7.535276743344381}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:38,166] Trial 491 finished with value: 2.5366692333179044 and parameters: {'learning_rate': 0.15409133882765888, 'subsample': 0.7966096431527994, 'colsample_bytree': 0.8072838293121412, 'max_depth': 9, 'min_child_weight': 280, 'gamma': 0.11093806149761884, 'alpha': 6.071861409420691, 'lambda': 8.265193219060803}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:38,435] Trial 492 finished with value: 2.538962460190713 and parameters: {'learning_rate': 0.17012447059061453, 'subsample': 0.8234036748919371, 'colsample_bytree': 0.9401438264551351, 'max_depth': 9, 'min_child_weight': 257, 'gamma': 0.1252380094594671, 'alpha': 5.367932722080924, 'lambda': 7.827705315697651}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:38,706] Trial 493 finished with value: 2.5388962730182887 and parameters: {'learning_rate': 0.19537039807401954, 'subsample': 0.7763689050455802, 'colsample_bytree': 0.9187816836189112, 'max_depth': 9, 'min_child_weight': 271, 'gamma': 0.1430942010518393, 'alpha': 6.650764205815868, 'lambda': 8.13547146318654}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:39,068] Trial 494 finished with value: 2.540531432490996 and parameters: {'learning_rate': 0.1376803476760772, 'subsample': 0.8079966040745484, 'colsample_bytree': 0.8883215416740958, 'max_depth': 9, 'min_child_weight': 139, 'gamma': 0.0973761274968034, 'alpha': 3.2894762116863494, 'lambda': 8.577085477418734}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:39,398] Trial 495 finished with value: 2.5364561398273957 and parameters: {'learning_rate': 0.12456802867347848, 'subsample': 0.7873923094117522, 'colsample_bytree': 0.8752939605293523, 'max_depth': 9, 'min_child_weight': 264, 'gamma': 0.13648657490799582, 'alpha': 5.789305853685679, 'lambda': 7.776093904960892}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:39,664] Trial 496 finished with value: 2.8743395672804892 and parameters: {'learning_rate': 0.024523106333722323, 'subsample': 0.6578715143896665, 'colsample_bytree': 0.9079992735318435, 'max_depth': 9, 'min_child_weight': 265, 'gamma': 0.11936525821993489, 'alpha': 5.86943397241302, 'lambda': 7.535640506703338}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:39,996] Trial 497 finished with value: 2.5368837099649357 and parameters: {'learning_rate': 0.1245518867514608, 'subsample': 0.7928848989044878, 'colsample_bytree': 0.878363875638419, 'max_depth': 9, 'min_child_weight': 276, 'gamma': 0.018773088247379888, 'alpha': 6.435133595271311, 'lambda': 7.827259680240152}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:40,265] Trial 498 finished with value: 2.5391362543048155 and parameters: {'learning_rate': 0.1477414909648023, 'subsample': 0.7518474748271392, 'colsample_bytree': 0.9655720945946835, 'max_depth': 9, 'min_child_weight': 286, 'gamma': 0.1559998938610851, 'alpha': 6.1511468506774944, 'lambda': 7.391350679726305}. Best is trial 423 with value: 2.534854115685296.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-31 11:51:40,586] Trial 499 finished with value: 2.5364272455287034 and parameters: {'learning_rate': 0.1287800770471552, 'subsample': 0.7823644801689634, 'colsample_bytree': 0.8955612397814355, 'max_depth': 9, 'min_child_weight': 272, 'gamma': 0.13406083278672415, 'alpha': 6.885366742458096, 'lambda': 7.672051362793116}. Best is trial 423 with value: 2.534854115685296.

# %%
best_params = study.best_params 
best_params["n_estimators"] = 100  
best_params["random_state"] = 42 
best_params["objective"] = "reg:squarederror" 
best_params["tree_method"] = "gpu_hist" 
print(f"best params = {best_params}")
# Out:
# best params = {'learning_rate': 0.2987633195855668, 'subsample': 0.7618827977160534, 'colsample_bytree': 0.7975880613795246, 'max_depth': 9, 'min_child_weight': 244, 'gamma': 0.1400177957602812, 'alpha': 4.2890899014765935, 'lambda': 5.8108967740757125, 'n_estimators': 100, 'random_state': 42, 'objective': 'reg:squarederror', 'tree_method': 'gpu_hist'}

# %%
# refit full 
full_x = np.concatenate([X_train, X_val], axis=0) 
full_y = np.concatenate([y_train, y_val], axis=0)

# %%
reg_xgb = XGBRegressor(**best_params) 
reg_xgb.fit(full_x, full_y, eval_set=[(full_x, full_y)], early_stopping_rounds=30, verbose=20)
# Out:
# [0]	validation_0-rmse:11.39392
# [20]	validation_0-rmse:3.23177
# [40]	validation_0-rmse:3.22530
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [60]	validation_0-rmse:3.22346
# [80]	validation_0-rmse:3.22266
# [99]	validation_0-rmse:3.22233
# XGBRegressor(alpha=4.2890899014765935, base_score=0.5, booster='gbtree',
#              callbacks=None, colsample_bylevel=1, colsample_bynode=1,
#              colsample_bytree=0.7975880613795246, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              gamma=0.1400177957602812, gpu_id=0, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              lambda=5.8108967740757125, learning_rate=0.2987633195855668,
#              max_bin=256, max_cat_to_onehot=4, max_delta_step=0, max_depth=9,
#              max_leaves=0, min_child_weight=244, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=42, ...)

# %%
# inference 
submission['일시'] = pd.to_datetime(submission['일시'])
submission['month'] = submission['일시'].dt.month
submission['day'] = submission['일시'].dt.day
submission['week_of_month'] = submission['일시'].dt.day.apply(lambda x: (x - 1) // 7 + 1)

# %%
submission
# Out:
#             일시  평균기온  month  day  week_of_month
# 0   2023-01-01     0      1    1              1
# 1   2023-01-02     0      1    2              1
# 2   2023-01-03     0      1    3              1
# 3   2023-01-04     0      1    4              1
# 4   2023-01-05     0      1    5              1
# ..         ...   ...    ...  ...            ...
# 353 2023-12-20     0     12   20              3
# 354 2023-12-21     0     12   21              3
# 355 2023-12-22     0     12   22              4
# 356 2023-12-23     0     12   23              4
# 357 2023-12-24     0     12   24              4
#
# [358 rows x 5 columns]

# %%
merged_submission = pd.merge(submission, grouped, on=['month', 'week_of_month'], how='left')
# Out:
# /tmp/ipykernel_711/741608829.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   merged_submission = pd.merge(submission, grouped, on=['month', 'week_of_month'], how='left')

# %%
merged_submission.drop(columns={"일시", "평균기온"}, inplace=True)

# %%
predictions = reg_xgb.predict(merged_submission)

# %%
answers = pd.read_csv("sample_submission.csv") 
answers["평균기온"] = predictions

# %%
answers
# Out:
#              일시      평균기온
# 0    2023-01-01 -2.293260
# 1    2023-01-02 -2.345223
# 2    2023-01-03 -2.367261
# 3    2023-01-04 -3.357687
# 4    2023-01-05 -3.200403
# ..          ...       ...
# 353  2023-12-20 -0.003871
# 354  2023-12-21 -0.104263
# 355  2023-12-22  0.147887
# 356  2023-12-23 -0.382040
# 357  2023-12-24 -0.863176
#
# [358 rows x 2 columns]

# %%
answers.to_csv("xgboost_optuna.csv", index=False)
