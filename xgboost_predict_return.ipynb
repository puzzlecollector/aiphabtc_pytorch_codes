# %%
import numpy as np 
import pandas as pd 
import pandas_ta as ta
import ccxt
from datetime import datetime
from xgboost import XGBRegressor
import optuna 
from tqdm.auto import tqdm
from sklearn.metrics import mean_absolute_error

# %%
chart_df = pd.read_feather('BTC_USDT-4h.feather')
chart_df['date'] = pd.to_datetime(chart_df['date'])
chart_df['date'] = chart_df['date'].dt.tz_localize(None) 

hours, days, months = [], [], [] 
for dt in tqdm(chart_df["date"]): 
    dtobj = pd.to_datetime(dt) 
    hour = dtobj.hour 
    day = dtobj.day 
    month = dtobj.month 
    hours.append(hour) 
    days.append(day) 
    months.append(month) 

chart_df["hours"] = hours 
chart_df["days"] = days 
chart_df["months"] = months 

# define targets 
close = chart_df.close.values 
targets = [] 

for i in range(len(close) - 1): 
    targets.append(close[i+1]) 
targets.append(None) 
chart_df["targets"] = targets
# Out:
#   0%|          | 0/13719 [00:00<?, ?it/s]

# %%
chart_df.head(2)
# Out:
#                  date     open     high      low    close     volume  hours  \
# 0 2017-08-17 04:00:00  4261.48  4349.99  4261.32  4349.99  82.088865      4
# 1 2017-08-17 08:00:00  4333.32  4485.39  4333.32  4427.30  63.619882      8
#
#    days  months  targets
# 0    17       8  4427.30
# 1    17       8  4352.34

# %%
# add some technical indicators 
chart_df.set_index(pd.DatetimeIndex(chart_df["date"]), inplace=True)

# feature engineering 
chart_df["bop"] = chart_df.ta.bop(lookahead=False)
chart_df["ebsw"] = chart_df.ta.ebsw(lookahead=False) 
chart_df["cmf"] = chart_df.ta.cmf(lookahead=False) 
chart_df["vwap"] = chart_df.ta.vwap(lookahead=False) 
chart_df["rsi/100"] = chart_df.ta.rsi(lookahead=False) / 100.0 
chart_df["high/low"] = chart_df["high"] / chart_df["low"] 
chart_df["low/open"] = chart_df["low"] / chart_df["open"] 
chart_df["hwma"] = chart_df.ta.hwma(lookahead=False) 
chart_df["hwma/close"] = chart_df["hwma"] / chart_df["close"] 
for l in range(1, 12): 
    for col in ["open", "high", "low", "close", "volume", "vwap"]: 
        val = chart_df[col].values 
        val_ret = [None for _ in range(l)] 
        for i in range(l, len(val)):
            if val[i-l] == 0: 
                ret = 1 
            else:
                ret = val[i] / val[i-l] 
            val_ret.append(ret) 
        chart_df["{}_change_{}".format(col, l)] = val_ret 
        
chart_df.drop(columns={"date"}, inplace=True) 
chart_df.dropna(inplace=True)
# Out:
# /tmp/ipykernel_471/612284486.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chart_df["ebsw"] = chart_df.ta.ebsw(lookahead=False)

# %%
chart_df.head(2)
# Out:
#                         open     high      low    close      volume  hours  \
# date
# 2017-08-23 16:00:00  4226.94  4259.58  4103.51  4117.07  174.637585     16
# 2017-08-23 20:00:00  4136.48  4178.65  4069.80  4114.01  152.616402     20
#
#                      days  months  targets       bop  ...  low_change_10  \
# date                                                  ...
# 2017-08-23 16:00:00    23       8  4114.01 -0.703979  ...       1.112373
# 2017-08-23 20:00:00    23       8  4113.58 -0.206431  ...       1.197000
#
#                      close_change_10  volume_change_10  vwap_change_10  \
# date
# 2017-08-23 16:00:00         1.065938          1.522754        1.075381
# 2017-08-23 20:00:00         1.083182          0.912660        1.102681
#
#                      open_change_11  high_change_11  low_change_11  \
# date
# 2017-08-23 16:00:00        1.049637        1.046454       1.038863
# 2017-08-23 20:00:00        1.030000        1.040500       1.103235
#
#                      close_change_11  volume_change_11  vwap_change_11
# date
# 2017-08-23 16:00:00         1.025167          1.725297        1.025898
# 2017-08-23 20:00:00         1.065146          1.330740        1.074368
#
# [2 rows x 84 columns]

# %%
train_size = int(chart_df.shape[0] * 0.8) 

train_df = chart_df.iloc[:train_size] 
val_df = chart_df.iloc[train_size:] 

train_df.shape, val_df.shape
# Out:
# ((10943, 84), (2736, 84))

# %%
train_columns = [] 
for col in chart_df.columns:
    if col != "targets": 
        train_columns.append(col)

# %%
X_train = train_df[train_columns] 
y_train = train_df["targets"] 

X_val = val_df[train_columns] 
y_val = val_df["targets"] 

X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((10943, 83), (10943,), (2736, 83), (2736,))

# %%
def objective(trial): 
    param = {
        "objective": "reg:squarederror",  # Objective for regression
        "n_estimators": 100, 
        "random_state": 42, 
        "tree_method": "gpu_hist",  # Assuming you have a compatible GPU
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.3, log=True), 
        "subsample": trial.suggest_float("subsample", 0.6, 1.0), 
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0), 
        "max_depth": trial.suggest_int("max_depth", 3, 10), 
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 300), 
        "gamma": trial.suggest_float("gamma", 0, 0.4), 
        "alpha": trial.suggest_float("alpha", 0, 10), 
        "lambda": trial.suggest_float("lambda", 1, 10), 
    }

    reg_xgb = XGBRegressor(**param)
    reg_xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=30, verbose=False)
    predictions = reg_xgb.predict(X_val) 
    mae = mean_absolute_error(y_val, predictions)
    return mae

# %%
study = optuna.create_study(direction="minimize") 
study.optimize(objective, n_trials=500)
# Out:
# [I 2023-12-22 14:03:44,964] A new study created in memory with name: no-name-77cde2dd-3aa5-4022-b30e-3d38578f9e7d
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:45,225] Trial 0 finished with value: 568.3288510113989 and parameters: {'learning_rate': 0.2739501995373563, 'subsample': 0.7699438812163704, 'colsample_bytree': 0.9895865032675099, 'max_depth': 7, 'min_child_weight': 238, 'gamma': 0.38779645962512266, 'alpha': 9.93639178334509, 'lambda': 7.781000155108699}. Best is trial 0 with value: 568.3288510113989.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:45,481] Trial 1 finished with value: 398.0204708773072 and parameters: {'learning_rate': 0.0475914296576656, 'subsample': 0.9703189018221157, 'colsample_bytree': 0.780629073765465, 'max_depth': 3, 'min_child_weight': 117, 'gamma': 0.2527596491826379, 'alpha': 8.286644946376443, 'lambda': 3.4848134323342363}. Best is trial 1 with value: 398.0204708773072.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:45,825] Trial 2 finished with value: 1147.730620202851 and parameters: {'learning_rate': 0.029878895731479168, 'subsample': 0.8169843052743213, 'colsample_bytree': 0.6661560892763311, 'max_depth': 5, 'min_child_weight': 151, 'gamma': 0.3406471617425236, 'alpha': 7.4231142459228385, 'lambda': 7.192002038834868}. Best is trial 1 with value: 398.0204708773072.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:46,078] Trial 3 finished with value: 536.7862747709933 and parameters: {'learning_rate': 0.2114996607758841, 'subsample': 0.7690798015616289, 'colsample_bytree': 0.6030616465665124, 'max_depth': 6, 'min_child_weight': 221, 'gamma': 0.2527641560708824, 'alpha': 0.6986254794768498, 'lambda': 2.999260781835852}. Best is trial 1 with value: 398.0204708773072.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03
. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:56,251] Trial 22 finished with value: 353.4216189521656 and parameters: {'learning_rate': 0.11158753849483856, 'subsample': 0.6605485500688474, 'colsample_bytree': 0.8117483171977655, 'max_depth': 8, 'min_child_weight': 50, 'gamma': 0.14490256317996927, 'alpha': 5.138359062046679, 'lambda': 1.1186973931472535}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:56,752] Trial 23 finished with value: 371.10405439053363 and parameters: {'learning_rate': 0.0543853175116202, 'subsample': 0.7021974313658711, 'colsample_bytree': 0.9450488891189875, 'max_depth': 7, 'min_child_weight': 94, 'gamma': 0.06212833845901148, 'alpha': 2.643003287165644, 'lambda': 2.05558649681479}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:57,392] Trial 24 finished with value: 382.4929630105537 and parameters: {'learning_rate': 0.14299592930367824, 'subsample': 0.6410033721736466, 'colsample_bytree': 0.857174403498069, 'max_depth': 9, 'min_child_weight': 32, 'gamma': 0.18128501702981534, 'alpha': 4.80622254122432, 'lambda': 6.316999331947639}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:57,817] Trial 25 finished with value: 396.0546633429276 and parameters: {'learning_rate': 0.2182359789653396, 'subsample': 0.684459277262294, 'colsample_bytree': 0.7342091509115586, 'max_depth': 8, 'min_child_weight': 60, 'gamma': 0.11646425411976756, 'alpha': 3.341489757602299, 'lambda': 4.622747563824024}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:58,307] Trial 26 finished with value: 436.43274024294124 and parameters: {'learning_rate': 0.04362191801182088, 'subsample': 0.7294645695554687, 'colsample_bytree': 0.7859493132453357, 'max_depth': 7, 'min_child_weight': 21, 'gamma': 0.07876339577498344, 'alpha': 7.077548531252249, 'lambda': 3.253070010744016}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:59,028] Trial 27 finished with value: 368.72595169156614 and parameters: {'learning_rate': 0.07479202868306105, 'subsample': 0.8984319591811645, 'colsample_bytree': 0.6777813048163568, 'max_depth': 10, 'min_child_weight': 97, 'gamma': 0.15405311771820598, 'alpha': 1.9043151238688383, 'lambda': 1.0032958552516298}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:59,486] Trial 28 finished with value: 377.64397425244425 and parameters: {'learning_rate': 0.09852444622378585, 'subsample': 0.633214569703351, 'colsample_bytree': 0.8828715100608129, 'max_depth': 9, 'min_child_weight': 67, 'gamma': 0.23054242930044516, 'alpha': 0.054094981735390846, 'lambda': 5.844181655027245}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:03:59,836] Trial 29 finished with value: 618.9776381179184 and parameters: {'learning_rate': 0.03636207796835766, 'subsample': 0.770872828709558, 'colsample_bytree': 0.976063025673105, 'max_depth': 7, 'min_child_weight': 134, 'gamma': 0.025712275318102357, 'alpha': 5.279155581643945, 'lambda': 7.230704608510765}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:00,727] Trial 30 finished with value: 384.0595454986751 and parameters: {'learning_rate': 0.24473144482984996, 'subsample': 0.7365793061233612, 'colsample_bytree': 0.8726629735633362, 'max_depth': 8, 'min_child_weight': 1, 'gamma': 0.12789379059008743, 'alpha': 3.999089639994179, 'lambda': 2.5525937034678305}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:01,186] Trial 31 finished with value: 353.8414957396747 and parameters: {'learning_rate': 0.12132902134042238, 'subsample': 0.6639452246152112, 'colsample_bytree': 0.8239822866665525, 'max_depth': 8, 'min_child_weight': 43, 'gamma': 0.14133732986217534, 'alpha': 5.2110262408063575, 'lambda': 1.5068435657214296}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:01,602] Trial 32 finished with value: 356.2106066109284 and parameters: {'learning_rate': 0.12511822516709017, 'subsample': 0.65723810366182, 'colsample_bytree': 0.7878549946795179, 'max_depth': 8, 'min_child_weight': 44, 'gamma': 0.16349915255061614, 'alpha': 4.461514989080792, 'lambda': 2.1516033692368266}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:02,152] Trial 33 finished with value: 384.68267925061684 and parameters: {'learning_rate': 0.2984295005641098, 'subsample': 0.6207663901487122, 'colsample_bytree': 0.8277692933671946, 'max_depth': 9, 'min_child_weight': 23, 'gamma': 0.1032710202693444, 'alpha': 9.678464339742867, 'lambda': 1.0009573879900804}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:02,438] Trial 34 finished with value: 372.2196697534037 and parameters: {'learning_rate': 0.1860789636889278, 'subsample': 0.7932378314340218, 'colsample_bytree': 0.7646614007011479, 'max_depth': 7, 'min_child_weight': 91, 'gamma': 0.07397871667364994, 'alpha': 7.2410070442753, 'lambda': 1.5660888854789141}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:02,979] Trial 35 finished with value: 348.41672279045594 and parameters: {'learning_rate': 0.060438272577742064, 'subsample': 0.692444231625873, 'colsample_bytree': 0.7991040689044924, 'max_depth': 8, 'min_child_weight': 59, 'gamma': 0.1870973655212875, 'alpha': 5.361605705888123, 'lambda': 3.739814079315013}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:03,365] Trial 36 finished with value: 461.9169819078947 and parameters: {'learning_rate': 0.06155596531721507, 'subsample': 0.694009321013436, 'colsample_bytree': 0.7335179639854674, 'max_depth': 7, 'min_child_weight': 185, 'gamma': 0.19279790172194639, 'alpha': 3.236418355587506, 'lambda': 3.6746829795995755}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:03,657] Trial 37 finished with value: 574.7489067354257 and parameters: {'learning_rate': 0.08320991478584729, 'subsample': 0.7214529075914563, 'colsample_bytree': 0.7912307774844722, 'max_depth': 6, 'min_child_weight': 236, 'gamma': 0.2762045726539934, 'alpha': 6.53296144129736, 'lambda': 4.8492611563036006}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:04,047] Trial 38 finished with value: 2241.231775787532 and parameters: {'learning_rate': 0.02368929687088004, 'subsample': 0.7500798486211179, 'colsample_bytree': 0.8325489255139772, 'max_depth': 9, 'min_child_weight': 107, 'gamma': 0.2587589450080512, 'alpha': 7.764224058857209, 'lambda': 3.193467441335188}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:04,395] Trial 39 finished with value: 1153.6403720217697 and parameters: {'learning_rate': 0.02995766107727756, 'subsample': 0.7940723964107749, 'colsample_bytree': 0.6799412669331902, 'max_depth': 5, 'min_child_weight': 136, 'gamma': 0.21290335758828297, 'alpha': 0.7865040433405609, 'lambda': 3.747922291698411}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:04,848] Trial 40 finished with value: 373.1162545544362 and parameters: {'learning_rate': 0.050508414009018475, 'subsample': 0.9896508700889821, 'colsample_bytree': 0.7686443716983539, 'max_depth': 6, 'min_child_weight': 15, 'gamma': 0.08906962178156543, 'alpha': 5.786034900413222, 'lambda': 5.770671547360872}. Best is trial 17 with value: 344.7292988167032.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:05,385] Trial 41 finished with value: 344.01298155667484 and parameters: {'learning_rate': 0.10753460408963146, 'subsample': 0.6537196027394019, 'colsample_bytree': 0.8004603847996512, 'max_depth': 8, 'min_child_weight': 56, 'gamma': 0.12886401567620306, 'alpha': 5.320298631924173, 'lambda': 1.5163390185716912}. Best is trial 41 with value: 344.01298155667484.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04
. Best is trial 46 with value: 341.1174707459567.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:11,577] Trial 52 finished with value: 350.9087246293631 and parameters: {'learning_rate': 0.09388668998928021, 'subsample': 0.9666933086975968, 'colsample_bytree': 0.8024198526118994, 'max_depth': 8, 'min_child_weight': 48, 'gamma': 0.1860845269770483, 'alpha': 4.061681374987945, 'lambda': 6.823387993196143}. Best is trial 46 with value: 341.1174707459567.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:11,912] Trial 53 finished with value: 347.1007307942708 and parameters: {'learning_rate': 0.08606418233844772, 'subsample': 0.9651682288111434, 'colsample_bytree': 0.8012104554770663, 'max_depth': 4, 'min_child_weight': 49, 'gamma': 0.190749017645217, 'alpha': 4.209177536299401, 'lambda': 6.707984477346261}. Best is trial 46 with value: 341.1174707459567.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:12,254] Trial 54 finished with value: 351.26269105788566 and parameters: {'learning_rate': 0.07833027972709945, 'subsample': 0.9976998273572975, 'colsample_bytree': 0.7773104377251414, 'max_depth': 4, 'min_child_weight': 29, 'gamma': 0.235442862859382, 'alpha': 3.632848158065606, 'lambda': 7.596921766230705}. Best is trial 46 with value: 341.1174707459567.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:12,613] Trial 55 finished with value: 401.2186191777458 and parameters: {'learning_rate': 0.1274273448388171, 'subsample': 0.9301673893239158, 'colsample_bytree': 0.7493369689914787, 'max_depth': 6, 'min_child_weight': 89, 'gamma': 0.16256343641409493, 'alpha': 2.886685925809129, 'lambda': 8.03560887861819}. Best is trial 46 with value: 341.1174707459567.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:12,953] Trial 56 finished with value: 397.30672600283253 and parameters: {'learning_rate': 0.04580392360164557, 'subsample': 0.9611142151208046, 'colsample_bytree': 0.8180079623516532, 'max_depth': 4, 'min_child_weight': 10, 'gamma': 0.2551720950021238, 'alpha': 6.030296031446062, 'lambda': 6.54716740662763}. Best is trial 46 with value: 341.1174707459567.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:13,218] Trial 57 finished with value: 339.4591563156753 and parameters: {'learning_rate': 0.07030998767737705, 'subsample': 0.6173800744765285, 'colsample_bytree': 0.697016588657065, 'max_depth': 3, 'min_child_weight': 40, 'gamma': 0.218638485729498, 'alpha': 4.266369745435719, 'lambda': 8.954433782060836}. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:13,429] Trial 58 finished with value: 361.9039366747761 and parameters: {'learning_rate': 0.0727097545867436, 'subsample': 0.8902599554479459, 'colsample_bytree': 0.6941957901613452, 'max_depth': 3, 'min_child_weight': 38, 'gamma': 0.20491682138304312, 'alpha': 4.291644998059747, 'lambda': 9.91674610559903}. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:13,689] Trial 59 finished with value: 388.9404817993878 and parameters: {'learning_rate': 0.13960548849934182, 'subsample': 0.6175740900258645, 'colsample_bytree': 0.6549755156956081, 'max_depth': 3, 'min_child_weight': 28, 'gamma': 0.268931883304085, 'alpha': 1.0631834539638838, 'lambda': 8.949921545686673}. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:14,034] Trial 60 finished with value: 3292.479455223752 and parameters: {'learning_rate': 0.01996156719029898, 'subsample': 0.9248311526573875, 'colsample_bytree': 0.758932368273502, 'max_depth': 4, 'min_child_weight': 70, 'gamma': 0.30961827390933755, 'alpha': 4.905871503637316, 'lambda': 9.171404872814703}. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:14,314] Trial 61 finished with value: 358.15898177654424 and parameters: {'learning_rate': 0.057154006361558325, 'subsample': 0.6525634805761429, 'colsample_bytree': 0.7956646520873477, 'max_depth': 3, 'min_child_weight': 55, 'gamma': 0.22308989403081006, 'alpha': 3.6538822825006068, 'lambda': 1.9217290987804743}. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04
. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:25,832] Trial 72 finished with value: 375.5821024933754 and parameters: {'learning_rate': 0.05030194878925225, 'subsample': 0.9493005835217925, 'colsample_bytree': 0.7805952990322355, 'max_depth': 10, 'min_child_weight': 9, 'gamma': 0.22915581638500268, 'alpha': 4.477612879875561, 'lambda': 7.074054947659994}. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:26,533] Trial 73 finished with value: 345.59498852110744 and parameters: {'learning_rate': 0.08339576289507365, 'subsample': 0.9204331228249774, 'colsample_bytree': 0.815076502885525, 'max_depth': 9, 'min_child_weight': 25, 'gamma': 0.17923953421858907, 'alpha': 3.923495350798169, 'lambda': 7.502541680433479}. Best is trial 57 with value: 339.4591563156753.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:04:27,140] Trial 74 finished with value: 360.62539719252555 and parameters: {'learning_rate': 0.10185276009332211, 'subsample': 0.8921966441228053, 'colsample_bytree': 0.8214000713637003, 'max_depth': 9, 'min_child_weight': 45, 'gamma': 0.17947287849294036, 'alpha': 1.6494970376595566, 'lambda': 7.492856427635744}. Best is trial 57 with value: 339.4591563156753.
# ...
#   warnings.warn(
# [I 2023-12-22 14:08:04,348] Trial 475 finished with value: 346.3048945198282 and parameters: {'learning_rate': 0.06488199477655668, 'subsample': 0.820201353218163, 'colsample_bytree': 0.6132120169962544, 'max_depth': 5, 'min_child_weight': 8, 'gamma': 0.21358114174302453, 'alpha': 1.726803041199124, 'lambda': 5.287463217736702}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:05,213] Trial 476 finished with value: 337.88052340323463 and parameters: {'learning_rate': 0.0725731536537791, 'subsample': 0.77239447010775, 'colsample_bytree': 0.6360645994021742, 'max_depth': 9, 'min_child_weight': 13, 'gamma': 0.20167032469496793, 'alpha': 1.2719635204185866, 'lambda': 4.400764551247135}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:05,562] Trial 477 finished with value: 334.48997157403596 and parameters: {'learning_rate': 0.08015379924351208, 'subsample': 0.8485338813362103, 'colsample_bytree': 0.6212920384837469, 'max_depth': 5, 'min_child_weight': 21, 'gamma': 0.23545426711469117, 'alpha': 1.5989913179345776, 'lambda': 4.602176080326791}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:05,911] Trial 478 finished with value: 361.2610389825475 and parameters: {'learning_rate': 0.050945447541486846, 'subsample': 0.8576707087424635, 'colsample_bytree': 0.6195248900311098, 'max_depth': 5, 'min_child_weight': 19, 'gamma': 0.2410662827709372, 'alpha': 1.6470022733137504, 'lambda': 4.774448456121957}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:06,268] Trial 479 finished with value: 348.29632465563316 and parameters: {'learning_rate': 0.0788326672899087, 'subsample': 0.850037687268238, 'colsample_bytree': 0.6092569222744953, 'max_depth': 5, 'min_child_weight': 11, 'gamma': 0.2349496609353633, 'alpha': 1.7966405220894603, 'lambda': 5.141521112081376}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:06,619] Trial 480 finished with value: 341.10274147078303 and parameters: {'learning_rate': 0.06929854558229723, 'subsample': 0.867273752484911, 'colsample_bytree': 0.6228292220287386, 'max_depth': 5, 'min_child_weight': 22, 'gamma': 0.25299088514212625, 'alpha': 6.496400789556929, 'lambda': 4.617601750094096}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:06,973] Trial 481 finished with value: 337.69301503677815 and parameters: {'learning_rate': 0.06432537989678667, 'subsample': 0.8747946362383763, 'colsample_bytree': 0.6131393634632584, 'max_depth': 5, 'min_child_weight': 15, 'gamma': 0.2303004116622665, 'alpha': 5.418404000471885, 'lambda': 5.0304289256889}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:07,328] Trial 482 finished with value: 331.57523553145563 and parameters: {'learning_rate': 0.0757216184806884, 'subsample': 0.8486658069454966, 'colsample_bytree': 0.6083529670187414, 'max_depth': 5, 'min_child_weight': 8, 'gamma': 0.24300465210408476, 'alpha': 1.5697398984093947, 'lambda': 4.944862868679061}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:07,614] Trial 483 finished with value: 517.3250709863852 and parameters: {'learning_rate': 0.09024646837248228, 'subsample': 0.8599219939111958, 'colsample_bytree': 0.6055997219307478, 'max_depth': 5, 'min_child_weight': 233, 'gamma': 0.22343922063419464, 'alpha': 1.6052696429007234, 'lambda': 5.195478123575343}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:07,908] Trial 484 finished with value: 344.6977507367051 and parameters: {'learning_rate': 0.08067858533942451, 'subsample': 0.8470490304851955, 'colsample_bytree': 0.6075680193913089, 'max_depth': 4, 'min_child_weight': 7, 'gamma': 0.23630645122725832, 'alpha': 2.0047933720321565, 'lambda': 4.227399292872095}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:08,301] Trial 485 finished with value: 337.14494047823007 and parameters: {'learning_rate': 0.060513735701699656, 'subsample': 0.8555212500549859, 'colsample_bytree': 0.6006410484263344, 'max_depth': 5, 'min_child_weight': 7, 'gamma': 0.23953807501793167, 'alpha': 1.8636474217702828, 'lambda': 5.379630605344556}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:08,658] Trial 486 finished with value: 338.19649760999175 and parameters: {'learning_rate': 0.07841945635370685, 'subsample': 0.8428809862599355, 'colsample_bytree': 0.614392856392305, 'max_depth': 5, 'min_child_weight': 6, 'gamma': 0.22660918737791724, 'alpha': 2.156857081725729, 'lambda': 4.504907089673509}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:09,011] Trial 487 finished with value: 345.8315442679779 and parameters: {'learning_rate': 0.06918221208852338, 'subsample': 0.848446944743028, 'colsample_bytree': 0.6127039571951585, 'max_depth': 5, 'min_child_weight': 66, 'gamma': 0.258259000574797, 'alpha': 1.6868721124331103, 'lambda': 4.761993833769548}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:09,400] Trial 488 finished with value: 334.3265995208562 and parameters: {'learning_rate': 0.08622127232374575, 'subsample': 0.8547440332009505, 'colsample_bytree': 0.6069129870195173, 'max_depth': 5, 'min_child_weight': 13, 'gamma': 0.2198223307019222, 'alpha': 2.5425150878293303, 'lambda': 1.6630511914686439}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:09,789] Trial 489 finished with value: 342.7845112904331 and parameters: {'learning_rate': 0.09532943839758445, 'subsample': 0.8658743260075866, 'colsample_bytree': 0.6001212092603756, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.2180650633220469, 'alpha': 2.4514948858825645, 'lambda': 2.3379449263413807}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:10,149] Trial 490 finished with value: 347.7295735819855 and parameters: {'learning_rate': 0.08658644212851471, 'subsample': 0.8584478871012601, 'colsample_bytree': 0.6080292100457615, 'max_depth': 5, 'min_child_weight': 11, 'gamma': 0.21716495219804477, 'alpha': 3.141936966708047, 'lambda': 5.330910765268754}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:10,498] Trial 491 finished with value: 350.5705359100877 and parameters: {'learning_rate': 0.10418295811617156, 'subsample': 0.8509773616423839, 'colsample_bytree': 0.616268768421487, 'max_depth': 5, 'min_child_weight': 12, 'gamma': 0.22714058405520668, 'alpha': 2.860752445539786, 'lambda': 5.092218521602803}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:10,873] Trial 492 finished with value: 342.4778111008315 and parameters: {'learning_rate': 0.09080159216987808, 'subsample': 0.8625336714880982, 'colsample_bytree': 0.6076604157587928, 'max_depth': 5, 'min_child_weight': 7, 'gamma': 0.23315370243179528, 'alpha': 2.634128583461604, 'lambda': 2.581966514723345}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:11,217] Trial 493 finished with value: 344.8925529256899 and parameters: {'learning_rate': 0.0831995611771325, 'subsample': 0.8442650386974576, 'colsample_bytree': 0.6178868006704913, 'max_depth': 5, 'min_child_weight': 14, 'gamma': 0.2226552590286262, 'alpha': 2.523906376638366, 'lambda': 6.204072084782065}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:11,650] Trial 494 finished with value: 344.83794025264984 and parameters: {'learning_rate': 0.0980494383413635, 'subsample': 0.8738724905130284, 'colsample_bytree': 0.6076301912653718, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.21222237850108616, 'alpha': 6.881379305302797, 'lambda': 1.6160819790508476}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:12,016] Trial 495 finished with value: 336.571158811335 and parameters: {'learning_rate': 0.0770207786900811, 'subsample': 0.7830457035741962, 'colsample_bytree': 0.6273434785140286, 'max_depth': 5, 'min_child_weight': 17, 'gamma': 0.24941907791845075, 'alpha': 2.5814280613271325, 'lambda': 2.0930011678294216}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:12,386] Trial 496 finished with value: 336.8205545989812 and parameters: {'learning_rate': 0.07510805758096535, 'subsample': 0.7827322592241468, 'colsample_bytree': 0.6263437414671061, 'max_depth': 5, 'min_child_weight': 20, 'gamma': 0.24409994254094453, 'alpha': 2.771250601084956, 'lambda': 1.3143815783466808}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:12,753] Trial 497 finished with value: 344.0002330186632 and parameters: {'learning_rate': 0.07285460980127512, 'subsample': 0.7682075289643604, 'colsample_bytree': 0.6304641054456842, 'max_depth': 5, 'min_child_weight': 20, 'gamma': 0.24662263076751828, 'alpha': 2.9185256586715465, 'lambda': 1.9660777763450947}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:13,120] Trial 498 finished with value: 341.1903126998812 and parameters: {'learning_rate': 0.07583704105454984, 'subsample': 0.7738371338691914, 'colsample_bytree': 0.6283483066324029, 'max_depth': 5, 'min_child_weight': 17, 'gamma': 0.23875016768468174, 'alpha': 3.3369548670714497, 'lambda': 1.9929714040647917}. Best is trial 416 with value: 331.3131138066521.
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2023-12-22 14:08:13,489] Trial 499 finished with value: 339.5043448750457 and parameters: {'learning_rate': 0.07518534305939945, 'subsample': 0.7786347723380831, 'colsample_bytree': 0.6362073367204469, 'max_depth': 5, 'min_child_weight': 21, 'gamma': 0.2480397188511168, 'alpha': 3.0905144301460656, 'lambda': 1.4096302768558073}. Best is trial 416 with value: 331.3131138066521.

# %%
print("done!")
# Out:
# done!

# %%
best_params = study.best_params 
best_params["n_estimators"] = 100  
best_params["random_state"] = 42 
best_params["objective"] = "reg:squarederror" 
best_params["tree_method"] = "gpu_hist" 
print(f"best params = {best_params}")
# Out:
# best params = {'learning_rate': 0.07574900358755156, 'subsample': 0.8487453149256451, 'colsample_bytree': 0.6242657667111873, 'max_depth': 5, 'min_child_weight': 17, 'gamma': 0.23279180432621427, 'alpha': 2.018985796203534, 'lambda': 4.959323678120456, 'n_estimators': 100, 'random_state': 42, 'objective': 'reg:squarederror', 'tree_method': 'gpu_hist'}

# %%
# refit full 
full_x = np.concatenate([X_train, X_val], axis=0) 
full_y = np.concatenate([y_train, y_val], axis=0)  

# sorry wrong name 
clf_xgb = XGBRegressor(**best_params) 

clf_xgb.fit(full_x, full_y, eval_set=[(full_x, full_y)], early_stopping_rounds=30, verbose=20)
# Out:
# [0]	validation_0-rmse:24022.08516
# [20]	validation_0-rmse:5083.88360
# [40]	validation_0-rmse:1151.97175
# [60]	validation_0-rmse:457.55739
# /usr/local/lib/python3.9/dist-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [80]	validation_0-rmse:380.26977
# [99]	validation_0-rmse:365.23183
# XGBRegressor(alpha=2.018985796203534, base_score=0.5, booster='gbtree',
#              callbacks=None, colsample_bylevel=1, colsample_bynode=1,
#              colsample_bytree=0.6242657667111873, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              gamma=0.23279180432621427, gpu_id=0, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              lambda=4.959323678120456, learning_rate=0.07574900358755156,
#              max_bin=256, max_cat_to_onehot=4, max_delta_step=0, max_depth=5,
#              max_leaves=0, min_child_weight=17, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=42, ...)

# %%
clf_xgb.save_model("XGBoost_regression_optuna") 

print("done saving!")
# Out:
# done saving!

# %%
# inference 
# get inference data 
bitget = ccxt.bitget()
ohlcv = bitget.fetch_ohlcv("BTC/USDT:USDT", "4h")
chart_df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

def preprocess(df):
    bitget = ccxt.bitget()
    dates = df["timestamp"].values
    utc_timestamps = []
    for timestamp in dates:
        # Convert to ISO 8601 format
        date_string = bitget.iso8601(int(timestamp))
        # Convert to datetime object without timezone conversion
        date_object = datetime.strptime(date_string, "%Y-%m-%dT%H:%M:%S.%fZ")
        # Format to string if needed (optional)
        formatted_utc_time = date_object.strftime("%Y-%m-%d %H:%M:%S")
        utc_timestamps.append(formatted_utc_time)
    # Update DataFrame
    df["date"] = utc_timestamps
    df = df.drop(columns={"timestamp"})
    return df

chart_df = preprocess(chart_df)

# %%
hours, days, months = [], [], [] 
for dt in tqdm(chart_df["date"]): 
    dtobj = pd.to_datetime(dt) 
    hour = dtobj.hour 
    day = dtobj.day 
    month = dtobj.month 
    hours.append(hour) 
    days.append(day) 
    months.append(month) 

chart_df["hours"] = hours 
chart_df["days"] = days 
chart_df["months"] = months
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# add some technical indicators 
chart_df.set_index(pd.DatetimeIndex(chart_df["date"]), inplace=True)
# feature engineering 
chart_df["bop"] = chart_df.ta.bop(lookahead=False)
chart_df["ebsw"] = chart_df.ta.ebsw(lookahead=False) 
chart_df["cmf"] = chart_df.ta.cmf(lookahead=False) 
chart_df["vwap"] = chart_df.ta.vwap(lookahead=False) 
chart_df["rsi/100"] = chart_df.ta.rsi(lookahead=False) / 100.0 
chart_df["high/low"] = chart_df["high"] / chart_df["low"] 
chart_df["low/open"] = chart_df["low"] / chart_df["open"] 
chart_df["hwma"] = chart_df.ta.hwma(lookahead=False) 
chart_df["hwma/close"] = chart_df["hwma"] / chart_df["close"] 
for l in range(1, 12): 
    for col in ["open", "high", "low", "close", "volume", "vwap"]: 
        val = chart_df[col].values 
        val_ret = [None for _ in range(l)] 
        for i in range(l, len(val)):
            if val[i-l] == 0: 
                ret = 1 
            else:
                ret = val[i] / val[i-l] 
            val_ret.append(ret) 
        chart_df["{}_change_{}".format(col, l)] = val_ret 
        
chart_df.drop(columns={"date"}, inplace=True) 
chart_df.dropna(inplace=True)
# Out:
# /tmp/ipykernel_471/1286648618.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   chart_df["ebsw"] = chart_df.ta.ebsw(lookahead=False)

# %%
chart_df.head(2)
# Out:
#                         open     high      low    close     volume  hours  \
# date
# 2023-12-12 12:00:00  41592.0  42070.4  41157.2  41357.6  26161.019     12
# 2023-12-12 16:00:00  41357.6  41464.3  40687.8  41157.5  36940.481     16
#
#                      days  months       bop     ebsw  ...  low_change_10  \
# date                                                  ...
# 2023-12-12 12:00:00    12      12 -0.256680  0.00000  ...       0.944894
# 2023-12-12 16:00:00    12      12 -0.257695  0.57735  ...       1.010172
#
#                      close_change_10  volume_change_10  vwap_change_10  \
# date
# 2023-12-12 12:00:00         0.944220          3.676342        0.950104
# 2023-12-12 16:00:00         0.972581          0.894687        0.983842
#
#                      open_change_11  high_change_11  low_change_11  \
# date
# 2023-12-12 12:00:00        0.946822        0.957103       0.940807
# 2023-12-12 16:00:00        0.944024        0.940617       0.934117
#
#                      close_change_11  volume_change_11  vwap_change_11
# date
# 2023-12-12 12:00:00         0.944024          8.250046        0.949874
# 2023-12-12 16:00:00         0.939652          5.191152        0.945592
#
# [2 rows x 83 columns]

# %%
chart_df.tail(4)
# Out:
#                         open     high      low    close     volume  hours  \
# date
# 2023-12-22 00:00:00  43868.9  44288.5  43746.2  44030.0  31238.118      0
# 2023-12-22 04:00:00  44030.0  44444.0  43556.9  43605.5  34385.447      4
# 2023-12-22 08:00:00  43605.5  43859.3  43482.0  43775.1  29259.987      8
# 2023-12-22 12:00:00  43775.1  43829.2  43435.0  43435.0  18554.701     12
#
#                      days  months       bop      ebsw  ...  low_change_10  \
# date                                                   ...
# 2023-12-22 00:00:00    22      12  0.297068  0.434185  ...       1.024789
# 2023-12-22 04:00:00    22      12 -0.478526  0.349391  ...       1.018370
# 2023-12-22 08:00:00    22      12  0.449510  0.020348  ...       0.999435
# 2023-12-22 12:00:00    22      12 -0.862760 -0.872611  ...       1.004579
#
#                      close_change_10  volume_change_10  vwap_change_10  \
# date
# 2023-12-22 00:00:00         1.026881          1.465271        1.031595
# 2023-12-22 04:00:00         0.989631          0.744320        1.020613
# 2023-12-22 08:00:00         1.000828          0.864698        1.015029
# 2023-12-22 12:00:00         0.994207          0.748255        1.012748
#
#                      open_change_11  high_change_11  low_change_11  \
# date
# 2023-12-22 00:00:00        1.033915        1.029051       1.032066
# 2023-12-22 04:00:00        1.025286        1.033094       1.020355
# 2023-12-22 08:00:00        1.016981        0.989248       1.016619
# 2023-12-22 12:00:00        0.993480        0.989889       0.998354
#
#                      close_change_11  volume_change_11  vwap_change_11
# date
# 2023-12-22 00:00:00         1.025286          0.942547        1.033220
# 2023-12-22 04:00:00         1.016981          1.612901        1.029719
# 2023-12-22 08:00:00         0.993480          0.633373        1.018922
# 2023-12-22 12:00:00         0.993052          0.548333        1.013885
#
# [4 rows x 83 columns]

# %%
x_input = chart_df.iloc[-4, :].values.reshape((1, -1)) 
x_input.shape
# Out:
# (1, 83)

# %%
# load model 
test_xgb = XGBRegressor()
test_xgb.load_model("XGBoost_regression_optuna")
